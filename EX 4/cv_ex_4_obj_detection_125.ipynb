# %%
import torch
import cv2

# Load the pre-trained YOLOv5 model (latest version)
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
def detect_objects_image(image_path):
    # Load the image
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    results = model(image_rgb)
    results.show()
    results.save()
    df = results.pandas().xywh[0]
    print(df)
detect_objects_image('/content/ani.jpg')
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2025-3-6 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# <PIL.Image.Image image mode=RGB size=1024x700>
# Saved 1 image to runs/detect/exp4
#        xcenter     ycenter       width      height  confidence  class   name
# 0   185.515015  423.719971  217.546982  301.139526    0.900050     17  horse
# 1   216.527847  534.507202  152.837555  165.470642    0.889239     18  sheep
# 2   314.655945  518.542358  153.846527  176.144470    0.885137     18  sheep
# 3   850.709106  571.470581  162.613831  134.087463    0.863030     14   bird
# 4   743.662476  563.837158  130.126404  138.426941    0.822538     14   bird
# 5   426.247986  453.995819  142.191498  230.875793    0.811361     18  sheep
# 6   620.650269  562.105713   46.852112  104.173340    0.780174     14   bird
# 7   573.783081  571.249512   92.238464   92.867554    0.770596     14   bird
# 8   568.815796  465.674591   81.771667  116.095886    0.714275     14   bird
# 9   872.614441  482.320862  146.917603  166.438477    0.647623     18  sheep
# 10  375.273926  598.847229  151.561035   86.143555    0.638366     16    dog
# 11  797.793457  439.706818  211.298523  181.068542    0.567415     18  sheep
# 12  873.905640  483.697693  147.064026  167.293671    0.513005     14   bird
# 13  693.525757  468.786499  112.147522  109.947784    0.496163     18  sheep
# 14  804.874756  439.708466  232.484131  187.418762    0.347965     14   bird
# 15  128.535736  610.450378   62.031693   70.493286    0.323267     14   bird
# 16  539.284729  436.263184   98.447174   88.128296    0.305498     18  sheep
